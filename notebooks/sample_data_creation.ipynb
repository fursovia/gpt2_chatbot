# %%
import pandas as pd

# %%
context = [
    "Hi, how are you doing?",
    "How's it going?", 
    "How are you doing today?", 
    "Everything's been good with you?"
]

answer = [
    "I'm fine. How about yourself?", 
    "I'm doing well. How about you?", 
    "I'm doing great. What about you?", 
    "I haven't been better. How about yourself?"
]

# %%
df = pd.DataFrame([context, answer]).T

df.columns = ['context', 'answer']

df

# %%
df.to_csv('../data/sample.csv', index=False)

# %% [markdown]
# ## dummy

# %%
import numpy as np

# %%
corpus = list(set(' '.join(pd.read_csv('../data/ubuntu/test.csv')['context'].tolist()).split()))

# %%
num_examples = 100

context = [' '.join(np.random.choice(corpus, 5)) for _ in range(num_examples)]
answer = [' '.join(np.random.choice(corpus, 5)) for _ in range(num_examples)]

# %%
df = pd.DataFrame([context, answer]).T

df.columns = ['context', 'answer']

df
# Out:
#                                               context  \
# 0       extfsd loginpw installad garbage maintainable
# 1                     friggen rute orion greppy model
# 2   unuseable fstereo weirdhavent devdevhdc cabext...
# 3                  breezygnome superdep adsp gift ave
# 4    here aukland rkindervery ozorg xwindowsystemcore
# 5    pppoff bearable ich addingrepositories notifying
# 6   doublecheck anot necessarily patgtofile iconth...
# 7            prepackaged usefull kernelorg devx greek
# 8   swapping ordinary audiosink usrlibpythontestpy...
# 9                      iwav mums hoacky mountain jove
# 10  itthere authoring etchotplugblacklistd fsckext...
# 11  formatting problematic httpfiarchiveubuntucom ...
# 12           execution develop comercial guile amoung
# 13                  intf smilies ontopic tea assholes
# 14            patiently massesi weirdest kbmouse tons
# 15                 magics anout homegaim linuxs filth
# ...

# %%
df.to_csv('../data/sample/data.csv', index=False)

# %% [markdown]
# # Quora

# %%
questions = pd.read_csv('../data/questions.csv')

# %%
questions.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
questions = questions[questions['is_duplicate'] == 1]

# %%
questions = questions[['question1', 'question2']]

# %%
questions.sample(5)
# Out:
#                                                 question1  \
# 132144                   No one answers me on Quora, why?
# 214332  What is the postal code format of the Philippi...
# 246515  What is the significance of the 13th day death...
# 337555                         Is there life after death?
# 373512  How do I square a number without usisng a calc...
#
#                                                 question2
# 132144  What does it mean when no one answers most of ...
# 214332  What is the postal code format from the Philip...
# 246515  Why is a ceremony observed on the 13th day for...
# 337555       If there is life after death, why do I live?
# 373512  How do I square a number without using a calcu...

# %%
questions.shape
# Out:
# (149306, 2)

# %%
questions.columns = ['context', 'answer']

# %%
questions.sample(frac=0.5).to_csv('../data/quora/data.csv', index=False)
